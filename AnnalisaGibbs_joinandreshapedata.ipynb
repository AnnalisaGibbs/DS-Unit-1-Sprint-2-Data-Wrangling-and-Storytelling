# %% [markdown]
# <a href="https://colab.research.google.com/github/Gibbsfam7/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/AnnalisaGibbs_joinandreshapedata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2019-07-29 23:36:22--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.109.157
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.109.157|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  69.5MB/s    in 2.8s
#
# 2019-07-29 23:36:30 (69.5 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01

# %%
# !ls -lh *.csv
# Out:
# -rw-r--r-- 1 502 staff 2.6K May  2  2017 aisles.csv
# -rw-r--r-- 1 502 staff  270 May  2  2017 departments.csv
# -rw-r--r-- 1 502 staff 551M May  2  2017 order_products__prior.csv
# -rw-r--r-- 1 502 staff  24M May  2  2017 order_products__train.csv
# -rw-r--r-- 1 502 staff 104M May  2  2017 orders.csv
# -rw-r--r-- 1 502 staff 2.1M May  2  2017 products.csv

# %%
from IPython.display import display, Image
url = 'https://cdn-images-1.medium.com/max/1600/1*vYGFQCafJtGBBX5mbl0xyw.png'
example = Image(url=url, width=600)

display(example)
# Out:
# <img src="https://cdn-images-1.medium.com/max/1600/1*vYGFQCafJtGBBX5mbl0xyw.png" width="600"/>

# %%
import pandas as pd
aisles = pd.read_csv('aisles.csv')
print(aisles.shape)
aisles.head()
# Out:
# (134, 2)
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
departments = pd.read_csv('departments.csv')
print(departments.shape)
departments.head()
# Out:
# (21, 2)
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
order_products__prior = pd.read_csv('order_products__prior.csv')
print(order_products__prior.shape)
order_products__prior.head()
# Out:
# (32434489, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
order_products__train = pd.read_csv('order_products__train.csv')
print(order_products__train.shape)
order_products__train.head()
# Out:
# (1384617, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
# !free -m
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:          13022        2402        7190           0        3430       12315
# Swap:             0           0           0

# %%
orders = pd.read_csv('orders.csv')
print(orders.shape)
orders.head()
# Out:
# (3421083, 7)
#    order_id  user_id  ... order_hour_of_day  days_since_prior_order
# 0   2539329        1  ...                 8                     NaN
# 1   2398795        1  ...                 7                    15.0
# 2    473747        1  ...                12                    21.0
# 3   2254736        1  ...                 7                    29.0
# 4    431534        1  ...                15                    28.0
#
# [5 rows x 7 columns]

# %%
products = pd.read_csv('products.csv')
print(products.shape)
products.head()
# Out:
# (49688, 4)
#    product_id  ... department_id
# 0           1  ...            19
# 1           2  ...            13
# 2           3  ...             7
# 3           4  ...             1
# 4           5  ...            13
#
# [5 rows x 4 columns]

# %% [markdown]
# database
# *   order_products__prior
#           (Columns) order_id, product_id
# *   products
#           (Columns) product_id,	product_name

# %%
final = pd.merge(order_products__prior[['order_id', 'product_id']], products[['product_id', 'product_name']], how='left', on='product_id')
final
# Out:
#           order_id  ...                                       product_name
# 0                2  ...                                 Organic Egg Whites
# 1                2  ...                              Michigan Organic Kale
# 2                2  ...                                      Garlic Powder
# 3                2  ...                                     Coconut Butter
# 4                2  ...                                  Natural Sweetener
# 5                2  ...                                            Carrots
# 6                2  ...                   Original Unflavored Gelatine Mix
# 7                2  ...           All Natural No Stir Creamy Almond Butter
# 8                2  ...                            Classic Blend Cole Slaw
# 9                3  ...  Total 2% with Strawberry Lowfat Greek Strained...
# 10               3  ...                             Unsweetened Almondmilk
# ...

# %%
# Banana
# Bag of Organic Bananas
# Organic Strawberries
# Organic Baby Spinach
# Organic Hass Avocado
# Organic Avocado
# Large Lemon
# Strawberries
# Limes
# Organic Whole Milk

len(final.loc[final['product_name'] == 'Banana'])
# len(final.loc[final['product_name'] == 'Bag of Organic Bananas'])
# len(final.loc[final['product_name'] == 'Organic Strawberries'])
# len(final.loc[final['product_name'] == 'Organic Baby Spinach'])
# len(final.loc[final['product_name'] == 'Organic Hass Avocado'])
# len(final.loc[final['product_name'] == 'Organic Avocado'])
# len(final.loc[final['product_name'] == 'Large Lemon'])
# len(final.loc[final['product_name'] == 'Strawberries'])
# len(final.loc[final['product_name'] == 'Limes'])
# len(final.loc[final['product_name'] == 'Organic Whole Milk'])

#Bananas
print('Bananas:', len(final.loc[final['product_name'] == 'Banana']))
# Out:
# Bananas: 472565

# %%
print('Bag of Organic Bananas:', len(final.loc[final['product_name'] == 'Bag of Organic Bananas']))
# Out:
# Bag of Organic Bananas: 379450

# %%
print('Organic Strawberries:', len(final.loc[final['product_name'] == 'Organic Strawberries']))
# Out:
# Organic Strawberries: 264683

# %%
print('Organic Baby Spinach:', len(final.loc[final['product_name'] == 'Organic Baby Spinach']))
# Out:
# Organic Baby Spinach: 241921

# %%
print('Organic Hass Avocado:', len(final.loc[final['product_name'] == 'Organic Hass Avocado']))
# Out:
# Organic Hass Avocado: 213584

# %%
print('Organic Avocado:', len(final.loc[final['product_name'] == 'Organic Avocado']))
# Out:
# Organic Avocado: 176815

# %%
print('Large Lemon:', len(final.loc[final['product_name'] == 'Large Lemon']))
# Out:
# Large Lemon: 152657

# %%
print('Strawberries:', len(final.loc[final['product_name'] == 'Strawberries']))
# Out:
# Strawberries: 142951

# %%
print('Limes:', len(final.loc[final['product_name'] == 'Limes']))
# Out:
# Limes: 140627

# %%
print('Organic Whole Milk:', len(final.loc[final['product_name'] == 'Organic Whole Milk']))
# Out:
# Organic Whole Milk: 137905

# %%
# !free -m
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:          13022        4075        5501           0        3445       12311
# Swap:             0           0           0

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

table1 = pd.DataFrame(
    [[np.nan, 2],
     [16,    11], 
     [3,      1]],
    index=['John Smith', 'Jane Doe', 'Mary Johnson'], 
    columns=['treatmenta', 'treatmentb'])

table2 = table1.T

# %%
table1
# Out:
#               treatmenta  treatmentb
# John Smith           NaN           2
# Jane Doe            16.0          11
# Mary Johnson         3.0           1

# %%
table2
# Out:
#             John Smith  Jane Doe  Mary Johnson
# treatmenta         NaN      16.0           3.0
# treatmentb         2.0      11.0           1.0

# %%
table2 = table1.reset_index()
table2
# Out:
#           index  treatmenta  treatmentb
# 0    John Smith         NaN           2
# 1      Jane Doe        16.0          11
# 2  Mary Johnson         3.0           1

# %%
tidy = table2.melt(id_vars='index')
tidy
# Out:
#           index    variable  value
# 0    John Smith  treatmenta    NaN
# 1      Jane Doe  treatmenta   16.0
# 2  Mary Johnson  treatmenta    3.0
# 3    John Smith  treatmentb    2.0
# 4      Jane Doe  treatmentb   11.0
# 5  Mary Johnson  treatmentb    1.0

# %%
tidy = tidy.rename(columns={'index': 'name', 'variable': 'trt', 'value': 'result'})
tidy['trt'] = tidy.trt.str.replace('treatment', '')
tidy
# Out:
#            name trt  result
# 0    John Smith   a     NaN
# 1      Jane Doe   a    16.0
# 2  Mary Johnson   a     3.0
# 3    John Smith   b     2.0
# 4      Jane Doe   b    11.0
# 5  Mary Johnson   b     1.0

# %%
wide = tidy.pivot_table(values='result', index='name', columns= 'trt')
wide
# Out:
# trt              a     b
# name
# Jane Doe      16.0  11.0
# John Smith     NaN   2.0
# Mary Johnson   3.0   1.0

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
flights.pivot_table(index='year', columns='month', values='passengers')
# Out:
# month  January  February  March  April  ...  September  October  November  December
# year                                    ...
# 1949       112       118    132    129  ...        136      119       104       118
# 1950       115       126    141    135  ...        158      133       114       140
# 1951       145       150    178    163  ...        184      162       146       166
# 1952       171       180    193    181  ...        209      191       172       194
# 1953       196       196    236    235  ...        237      211       180       201
# 1954       204       188    235    227  ...        259      229       203       229
# 1955       242       233    267    269  ...        312      274       237       278
# 1956       284       277    317    313  ...        355      306       271       306
# 1957       315       301    356    348  ...        404      347       305       336
# 1958       340       318    362    348  ...        404      359       310       337
# ...
